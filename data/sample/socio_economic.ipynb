# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\DELL\OneDrive\Desktop\Project sem 2\data\Panel Data\Final_Master_Panel_AllColumns.csv")

df.head(20)
# Out:
#         Country  Year Country Code  GDP  Attacks Total_Population  \
# 0   Afghanistan  1970          AFG  NaN      NaN   1,12,90,128.00
# 1   Afghanistan  1971          AFG  NaN      NaN   1,15,67,667.00
# 2   Afghanistan  1972          AFG  NaN      NaN   1,18,53,696.00
# 3   Afghanistan  1973          AFG  NaN      1.0   1,21,57,999.00
# 4   Afghanistan  1974          AFG  NaN      NaN   1,24,69,127.00
# 5   Afghanistan  1975          AFG  NaN      NaN   1,27,73,954.00
# 6   Afghanistan  1976          AFG  NaN      NaN   1,30,59,851.00
# 7   Afghanistan  1977          AFG  NaN      NaN   1,33,40,756.00
# 8   Afghanistan  1978          AFG  NaN      NaN   1,36,11,441.00
# 9   Afghanistan  1979          AFG  NaN      3.0   1,36,55,567.00
# 10  Afghanistan  1980          AFG  NaN      NaN   1,31,69,311.00
# 11  Afghanistan  1981          AFG  NaN      NaN   1,19,37,581.00
# 12  Afghanistan  1982          AFG  NaN      NaN   1,09,91,378.00
# 13  Afghanistan  1983          AFG  NaN      NaN   1,09,17,982.00
# 14  Afghanistan  1984          AFG  NaN      NaN   1,11,90,221.00
# 15  Afghanistan  1985          AFG  NaN      NaN   1,14,26,852.00
# 16  Afghanistan  1986          AFG  NaN      NaN   1,14,20,074.00
# 17  Afghanistan  1987          AFG  NaN      1.0   1,13,87,818.00
# 18  Afghanistan  1988          AFG  NaN     11.0   1,15,23,298.00
# 19  Afghanistan  1989          AFG  NaN     10.0   1,18,74,088.00
#
#     Poverty_Headcount  Secondary_Enrollment  Unemployment_Rate  \
# 0                 NaN              8.364100                NaN
# 1                 NaN              9.378270                NaN
# 2                 NaN             10.414240                NaN
# 3                 NaN             10.932180                NaN
# 4                 NaN             11.094880                NaN
# 5                 NaN             11.595590                NaN
# 6                 NaN             12.458260                NaN
# 7                 NaN             13.259270                NaN
# 8                 NaN             13.821340                NaN
# 9                 NaN                   NaN                NaN
# 10                NaN             16.732780                NaN
# 11                NaN             20.092079                NaN
# 12                NaN             12.295000                NaN
# 13                NaN                   NaN                NaN
# 14                NaN             13.649400                NaN
# 15                NaN             13.496970                NaN
# 16                NaN             12.138570                NaN
# 17                NaN                   NaN                NaN
# 18                NaN             13.213960                NaN
# 19                NaN             12.681120                NaN
#
#     Inequality_Measure
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10              0.4095
# 11              0.4095
# 12              0.4095
# 13              0.4095
# 14              0.4095
# 15              0.4095
# 16              0.4095
# 17              0.4095
# 18              0.4095
# 19              0.4095
