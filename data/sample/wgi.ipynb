# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\DELL\OneDrive\Desktop\Project sem 2\data\Panel Data\WGI_master_panel.xlsx")

df.head(20)
# Out:
#         Country  Year  Control of corruption  Rule of law  \
# 0   afghanistan  2004                  0.000        0.075
# 1   afghanistan  2005                  0.000        0.075
# 2   afghanistan  2006                  0.000        0.025
# 3   afghanistan  2007                    NaN          NaN
# 4   afghanistan  2008                    NaN          NaN
# 5   afghanistan  2009                  0.000        0.075
# 6   afghanistan  2010                  0.000        0.075
# 7   afghanistan  2011                  0.000        0.075
# 8   afghanistan  2012                  0.000        0.075
# 9   afghanistan  2013                  0.000        0.075
# 10  afghanistan  2014                  0.000        0.075
# 11  afghanistan  2015                  0.000        0.075
# 12  afghanistan  2016                  0.000        0.075
# 13  afghanistan  2017                  0.000        0.075
# 14  afghanistan  2018                  0.000        0.075
# ...
