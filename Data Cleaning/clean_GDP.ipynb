# %%
import pandas as pd
gdp_raw = pd.read_excel(r"C:\Users\DELL\OneDrive\Desktop\Project sem 2\Terrorism_repo\Data Cleaning\data\GDP.xlsx")
gdp_raw.head()
gdp_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 69 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Data Source                   268 non-null    object
#  1   World Development Indicators  268 non-null    object
#  2   Unnamed: 2                    267 non-null    object
#  3   Unnamed: 3                    267 non-null    object
#  4   Unnamed: 4                    152 non-null    float64
#  5   Unnamed: 5                    155 non-null    float64
#  6   Unnamed: 6                    157 non-null    float64
#  7   Unnamed: 7                    157 non-null    float64
#  8   Unnamed: 8                    157 non-null    float64
#  9   Unnamed: 9                    163 non-null    float64
#  10  Unnamed: 10                   164 non-null    float64
#  11  Unnamed: 11                   168 non-null    float64
# ...
